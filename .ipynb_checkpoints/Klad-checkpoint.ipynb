# %%
import pandas as pd

# %%
df = pd.read_csv("dailyActivity_selection.csv").drop(["Unnamed: 0","Unnamed: 0.1"])

# %%
df
# Out:
#      Unnamed: 0  Unnamed: 0.1          Id ActivityDate  TotalSteps  \
# 0             0             0  1503960366      4/12/16       13162
# 1             1             1  1503960366      4/13/16       10735
# 2             2             2  1503960366      4/15/16        9762
# 3             3             3  1503960366      4/16/16       12669
# 4             4             4  1503960366      4/17/16        9705
# ..          ...           ...         ...          ...         ...
# 388         388           388  8792009665      4/30/16        7174
# 389         389           389  8792009665       5/1/16        1619
# 390         390           390  8792009665       5/2/16        1831
# 391         391           391  8792009665       5/3/16        2421
# 392         392           392  8792009665       5/4/16        2283
#
#      VeryActiveMinutes  SedentaryMinutes  TotalMinutesAsleep  \
# 0                   25               728                 327
# ...
