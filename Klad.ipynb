# %%
import pandas as pd

# %%
df = pd.read_csv("dailyActivity_selection.csv")

# %%
# df['ActivityDate'] = pd.to_datetime(df['ActivityDate'])

# %%
# df.to_csv("dailyActivity_selection.csv")

# %%
df
# Out:
#      Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1          Id ActivityDate  \
# 0             0             0               0  1503960366   2016-04-12
# 1             1             1               1  1503960366   2016-04-13
# 2             2             2               2  1503960366   2016-04-15
# 3             3             3               3  1503960366   2016-04-16
# 4             4             4               4  1503960366   2016-04-17
# ..          ...           ...             ...         ...          ...
# 388         388           388             388  8792009665   2016-04-30
# 389         389           389             389  8792009665   2016-05-01
# 390         390           390             390  8792009665   2016-05-02
# 391         391           391             391  8792009665   2016-05-03
# 392         392           392             392  8792009665   2016-05-04
#
#      TotalSteps  VeryActiveMinutes  SedentaryMinutes  TotalMinutesAsleep  \
# ...
